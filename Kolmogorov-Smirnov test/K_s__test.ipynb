# %%
import scipy as sc
import numpy as np
import pandas as pd
from scipy.stats import ks_2samp

# %%
data_dir = 'https://github.com/henrii1/WTPCM-using-multivariate-DM-and-K-S-test/blob/main/Dataset/k_s_data.xlsx?raw=true'
dat = pd.read_excel(data_dir)
data = np.array(dat)
data
# Out:
# array([[1905.50061035, 2014.80505371, 2042.95495605, ..., 2032.02880859,
#         1998.73095703, 2042.95495605],
#        [1942.29382324, 2045.39318848, 2044.49157715, ..., 2016.88537598,
#         1951.82043457, 2044.49157715],
#        [1866.86218262, 2049.99316406, 2033.0880127 , ..., 2045.43225098,
#         1957.94250488, 2033.0880127 ],
#        ...,
#        [          nan,           nan,           nan, ...,           nan,
#                   nan,           nan],
#        [          nan,           nan,           nan, ...,           nan,
#                   nan,           nan],
#        [          nan,           nan,           nan, ...,           nan,
#                   nan,           nan]])

# %%
A = data[:2937, 0]
A
# Out:
# array([1905.50061035, 1942.29382324, 1866.86218262, ..., 2012.60107422,
#        2014.97814941, 2029.78881836])

# %%
B = data[:65, 1]
B
# Out:
# array([2014.80505371, 2045.39318848, 2049.99316406, 2046.18151855,
#        2026.80212402, 2010.92687988, 2030.94360352, 1981.31188965,
#        2003.14807129, 1974.51477051, 1989.42529297, 2005.35668945,
#        2004.45092773, 1939.75817871, 1990.1027832 , 2005.1887207 ,
#        1977.59716797, 2022.13317871, 2033.27783203, 1892.21166992,
#        1954.75244141, 1898.49108887, 1919.64086914, 1953.76257324,
#        1944.1439209 , 1951.48376465, 1953.49365234, 1982.12353516,
#        1965.49890137, 1915.15380859, 1902.66711426, 1982.0291748 ,
#        1967.37097168, 1970.71203613, 1975.11816406, 1969.9329834 ,
#        1908.25866699, 1889.88757324, 1971.20629883, 1935.73449707,
#        1984.2890625 , 1988.1953125 , 2000.43359375, 2003.36901855,
#        1946.42932129, 2028.90002441, 2010.02307129, 2002.44104004,
#        2008.77380371, 2038.13635254, 2024.09899902, 2026.94506836,
#        2026.45129395, 1966.18859863, 2047.07397461, 1971.3704834 ,
# ...

# %%
C = data[:65, 2]
C
# Out:
# array([2042.95495605, 2044.49157715, 2033.0880127 , 2049.85180664,
#        2057.83959961, 2049.06982422, 2061.19628906, 2047.19238281,
#        2050.71923828, 2031.38903809, 2051.52685547, 2049.44824219,
#        2036.28881836, 2041.9342041 , 2052.26879883, 2057.07373047,
#        2051.25976562, 2047.48974609, 2046.97070312, 2051.55664062,
#        2041.68518066, 2060.66894531, 2045.41333008, 2039.29504395,
#        2070.83837891, 2050.20629883, 2070.16821289, 2004.63171387,
#        2038.5489502 , 2029.25842285, 2032.39416504, 2027.30957031,
#        2036.17077637, 2045.54919434, 2033.26220703, 2058.28662109,
#        2030.24584961, 2063.48950195, 2044.4296875 , 2050.65625   ,
#        2024.22106934, 2055.38696289, 2048.26635742, 2034.32763672,
#        2042.81176758, 2030.93334961, 2016.22595215, 2045.33654785,
#        2053.04345703, 2040.4432373 , 2023.59069824, 2027.5489502 ,
#        2003.18530273, 2006.74450684, 2014.82800293, 1999.10400391,
#        2005.94445801, 2003.87414551, 2015.20324707, 2008.54919434,
#        2008.65209961, 2008.45178223, 2009.2980957 , 2021.02990723,
#        2025.00476074, 2018.01257324, 2013.73547363, 2038.81396484,
#        2012.30871582, 2015.58605957, 2024.48217773, 2026.08752441,
#        2006.89709473, 2004.50268555, 2017.81506348, 2038.94616699,
#        2031.28161621, 2028.07580566, 2022.22241211, 2033.97924805,
#        2029.38684082, 2026.99597168, 2041.51501465, 2047.05322266,
# ...

# %%
H = data[:65, 7]
H
# Out:
# array([1998.73095703, 1951.82043457, 1957.94250488, 1934.35119629,
#        1966.1907959 , 2008.03051758, 1917.08618164, 1961.39501953,
#        1992.49523926, 1857.09277344, 2007.5949707 , 1991.67443848,
#        2001.06945801, 2017.19641113, 2005.01220703, 1997.65393066,
#        1936.15649414, 1965.70349121, 1979.07202148, 1947.09667969,
#        1953.24865723, 1945.94165039, 1992.72167969, 1963.13305664,
#        1891.05517578, 1943.94018555, 1981.78540039, 1977.9387207 ,
#        1971.80029297, 1990.48217773, 2014.33581543, 1951.30065918,
#        1952.88549805, 1994.28308105, 1969.1114502 , 2018.0703125 ,
#        2004.2454834 , 1950.31384277, 1952.64001465, 1984.08666992,
#        1980.85583496, 1998.39245605, 1975.11682129, 1979.4901123 ,
#        1956.98901367, 1951.23254395, 1946.45861816, 1984.29528809,
#        1922.07800293, 1910.93151855, 2000.75      , 1939.26098633,
#        1809.37768555, 1881.83239746, 1882.55969238, 2010.9354248 ,
# ...

# %%
I = data[:1377, 8]
I
# Out:
# array([2042.95495605, 2044.49157715, 2033.0880127 , ..., 2042.83972168,
#        2045.87585449, 2051.13476562])

# %%
sc.stats.ks_2samp(A, B, alternative='two-sided')
# Out:
# KstestResult(statistic=0.08768235509808543, pvalue=0.6788814342058427)

# %%
sc.stats.ks_2samp(I, C, alternative='two-sided')
# Out:
# KstestResult(statistic=0.045986257750963634, pvalue=0.9986177765457991)

# %%
sc.stats.ks_2samp(E, F, alternative = 'two-sided')
# Out:
# KstestResult(statistic=0.08312284730195178, pvalue=0.7394264138296116)

# %%
sc.stats.ks_2samp(E, G, alternative = 'two-sided')
# Out:
# KstestResult(statistic=0.12356167878555938, pvalue=0.2630317632508018)

# %%
sc.stats.ks_2samp(A, H, alternative = 'two-sided')
# Out:
# KstestResult(statistic=0.2281501270265315, pvalue=0.002159840250838485)

# %%
sc.stats.ks_2samp(E, D, alternative = 'two-sided')
# Out:
# KstestResult(statistic=0.17875816993464053, pvalue=0.02481934294145194)
